# %%
import pandas as pd
import numpy as np

# %%
df_fsa = pd.read_csv('ProjetosRenunciaFiscal.csv', sep=';')
df_fsa_es = df_fsa[df_fsa['UF_PROPONENTE'] == 'ES']
df_fsa_es
# Out:
#      NUMERO_SALIC                                     TITULO_PROJETO  \
# 198       02-4052  A Rebelião dos Estudantes      (Ex - Rebelião ...
# 806       07-0279                                       Outro Sertão
# 1231      10-0407                                             Punhal
# 1562      12-0516                                             HELENA
# 1816      14-0222                 Uma Verdadeira Jornada Fantásticas
# 2487      17-0202  A Incrível Jornada - A História das Baleias Ca...
# 3595      95-0673                                Amor está no Ar (O)
# 3642      96-0472                                          Rerigtiba
# 3732      97-0586                        Morte da Mulata (A) - Filme
#
#      DATA_PUB_APROVACAO_PROJETO DATA_PRIMEIRA_LIBERACAO  \
# 198                  26/11/2002              06/02/2006
# 806                  22/10/2007              15/01/2008
# 1231                 08/12/2010              10/08/2011
# ...

# %%
df_fsa_investidores = pd.read_csv('InvestidoresEmProjetosRenunciaFiscal.csv', sep=';')
df_fsa_investidores
# Out:
#                                            CONTRIBUINTE   CNPJ_CONTRIBUINTE  \
# 0                       Fernanda Lucia Baptista Pereira       PESSOA FÍSICA
# 1                         14 BRASIL TELECOM CELULAR S/A  05.423.963/0005-45
# 2                                          3M do Brasil  45.985.371/0001-08
# 3                             4 ELOS DISTRIBUIDORA LTDA  23.048.790/0001-80
# 4                            : BANCO RIBEIRAO PRETO S/A  00.517.645/0001-04
# ...                                                 ...                 ...
# 4555                  Águas de Penha Saneamento SPE S.A  23.486.042/0001-80
# 4556                 Águas de São Francisco do Sul LTDA  21.180.700/0001-85
# 4557                    Águia Branca Participações S.A.  31.469.364/0001-49
# 4558                               Érica dos Santos Abe       PESSOA FÍSICA
# 4559  ÚNICO DISTRIBUIDORA DE TÍTULOS E VALORES MOBIL...  33.318.163/0001-76
#
# ...

# %%
fabrica_1 = [11,8,12,10,9,7,6,7,8,13,14,15]
var = np.var(fabrica_1)
var
# Out:
# 8.166666666666666

# %%
fabrica_2 = [11,6,11,14,12,17,10,11,10,12,14,16]
var_2 = np.var(fabrica_2)
var_2
# Out:
# 8.0

# %%
co_var = np.cov(fabrica_1, fabrica_2)
co_var
# Out:
# array([[8.90909091, 3.36363636],
#        [3.36363636, 8.72727273]])
